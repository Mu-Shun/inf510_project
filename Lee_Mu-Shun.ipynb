# %% [markdown]
# 1. **The names of team member(s)**:
#
# Mu-Shun Lee
#
# 2.	**How to run your code (what command-line switches they are, what happens when you invoke the code, etc.)**
#
#     This project requires the following packages:
#     - pandas, numpy, sqlite, requests and beautifulsoup
#
#     The github link is https://github.com/Mu-Shun/inf510_project
#
# Run the Mu-Shun_Lee_hw5.py to produce an MLB.db. The database will contain the data from 1980 to 2019. Then open the jupyter notebook-Lee_Mu-Shun and run in all to see the result, it will get the function from Analysis_function.py. I would use a jupyter notebook to present the result due to it is more readable, also some of the information below is covered in the notebook. The database first collects the top 100 ERA/AVG pitchers and players from 1980 till 2019.
#
# Secondly, enter into their URL and grab their annual data of batting/pitching/fielding based on each player.
# (So there will be thousands of URLs to grab to get their information) Last but not least, grab their data through the external API.
#
# 3.	**Any major “gotchas” to the code (i.e. things that don’t work, go slowly, could be improved, etc.)**
#
# I think the biggest problem is that the real-world data usually are not that completed. For example, some MLB players before 1994 did not have their fielding data. Although it is reasonable to get the information if the MLB wants to do it, I consider it cause too much work for them to do.
#
# Another instance, some players did not have their detail information. (Such as his birth state, birth country) These conditions might cause some impact on the result. As I was researching the distribution of the player's birth country, most of the players from the USA may have fully recorded. As some of the players from other countries may not record completely, thus the result may overestimate the percentage from the USA.
#
# Another problem is that data collection is not that quick. (However, I have optimized it through dictionaries to decrease its time complexity) With the partial data, (collect the top 100 ERA/AVG pitchers and players from 1980 till 2019) of running 40 years may consume like about 15 minutes. If I want to collect all the data of the players from each year, I think the time consuming will be considerable.
#
# 4.  **Anything else you feel is relevant to the grading of your project your project.**
#
# I think I did great work on optimizing the time complexity in this project.
# Since in (2), I have said that there are several links to connect and grab, an efficient code is a must.
# Originally I need about 2 hours to grab the data I want. But as remembering the professor and the TA says that dictionaries could be a good data form for saving.
# I decrease my time complexity with it. It is such a big task. After conquering, I filled full of achievement and happiness.
#
# 5. **What did you set out to study?  (i.e. what was the point of your project?  This should be close to your Milestone 1 assignment, but if you switched gears or changed things, note it here.)**
#
# There are 7 points that I want to study for. I have increased two more from milestone 1.
#
# (1). Annual All-Star team based on the player's statistics.
#
# (2). Historical All-Star team, use the similar model above to run out an All-Star team in the whole period.
#
# (3). Specific Team's All-Star uses a similar model to find an All-star team in a specific team.
#
# (4). Build the rank list of the country/city would have produced good players to MLB.
#
# (5). Find the Expect year that a good player/pitcher can be employed in MLB.
#
# (6). Find the Expect year that a good player/pitcher can be ranked in the top 100 of AVG/ERA. (Highly contributed expect year)
#
# (7). Get Total WAR for the team in a specific year.
#
#
# 6. **What did you Discover/what were your conclusions (i.e. what were your findings?  Were your original assumptions confirmed, etc.?)**
#
# For the (1),(2),(3) at 5, It was just doing it for fun! Since I have been baseball fans for a long period, I want to know how would the All-Period stars team look like. Comparing all the player's statistics through the period is less meaning but entertains.
#
# For the (4), we can find that most of the MLB players are from the USA, and there are about 22% of the stars are from California! Even almost doubles of the second-highest state. Surprisingly, the second place is in Florida, I thought it may be Texas when I was doing the research. By these statistics, a team could distribute their scouts due to the percentage of where might produce more stars to optimize their efficiency. However, there are still too many players do not have their birth record. Moreover, just as I mentioned above, some of the players from other countries may not be recorded, thus the result may overestimate the percentage of stars from the USA.
#
# For (5) and (6), I find that top players (such as ranked at list once in top 100 AVG), usually can survive in MLB for about 11.16 years. However, for top pitchers (such as ranked at list once in the top 100 ERA), those pitchers can only survive in MLB for about 7.25 years. But on the other hand, although for each top player can survive in MLB for about 11.16 years, they can only be ranked as top players for about 3.19 years.  In other words, they only contribute much for about three years to their team. This means that for the rest of their 8 years, they are not likely to be the Main Players of their team. They are just bench players.
#
# We also know that for each top pitchers can survive in MLB for about 10.16 years. Amazingly, they can be ranked as top pitchers for about 4.02 years, which is more than the average of players! In other words, they contribute a lot to more than half of their career time. The conclusion of (5) and (6). We can know that a good pitcher can contribute more than a good player (or batter) on average. But their career life surprisingly less than a player.
#
# Some possible assumption may due to pitchers are more likely to be injured, and the positions are fewer than fielders,
# thus a good pitcher can usually stand for their team for a long period and crowd out some rookies' opportunity.
# In my original assumption, I consider a good player would contribute more and survive more in their MLB career!
# The result surprised me a lot!
#
# For (7) I just want to mention that the total WAR of the batters has a high correlation to their team's performance.
# NYY HOU and LAD are all the first play in their division, and gets the highest total WAR in 2019.
#
# 7. **What difficulties did you have in completing the project?**
#
# The biggest difficulty is to diminish the time complexity of grabbing the data. Since there is too much data, it is time-consuming.
# However, saving the data as a dictionary type can save me more time.
# Secondly, there are many missing blanks of the player's data from external API, this could also impact the result.
#
# 8. **What skills did you wish you had while you were doing the project?**
#
# I hope that for the missing blanks on the player's data, I could write a code and it can search from google and grab down their information which is missed from different websites.
# I consider this method is practicable but due to my limited knowledge in algorithm and human source, I cannot do it.
# If I could do so, the result of the analyzing will be even more convincing.
#
# 9. **What would you do “next” to expand or augment the project?**
#
# The next step probably is to increase the data volume.
# Moreover, doing some feature engineering is also important for us to do further analyzing.

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import pandas as pd
from src import Analysis_function #import function from Analysis_fucntion

# %%
conn = sqlite3.connect('data/MLB.db')
cur = conn.cursor()

# %% [markdown]
# ~~~
# The database first collects the top 100 ERA/AVG pitchers and players from 1980 till 2019.
# Secondly, enter into their URL and grab their annual data of batting/pitching/fielding based on each player.
# (So there will be thousands of URLs to grab to get their information)
# Last but not least, grab their data through the external API.
#
#
# (1). Annual All-Star team based on the player's statistics.
# (2). Historical All-Star team, use the similar model above to run out an All-Star team in the whole period.
# (3). Specific Team's All-Star uses a similar model to find an All-star team in a specific team.
# (4). Build the rank list of the country/city would have produced good players to MLB.
# (5). Find the Expect year that a good player/pitcher can be employed in MLB.
# (6). Find the Expect year that a good player/pitcher can be ranked in the top 100 of AVG/ERA.
#     (Highly contributed expect year)
# (7). Get Total WAR for the team in a specific year.
# ~~~

# %% [markdown]
# ### 1. Annual All-Star team based on the player's statistics.
#
# ##### In Annual All-Star Team, we will select the top total of WAR and DWAR of each position from all the players. Moreover, the games played in that position must more than 81 games (half of the games per year)
#
# ##### For the Pitcher, we will only consider their WAR

# %%
print('Best Pitcher, Name, WAR')
print(Analysis_function.All_Star_team_Pitcher(2017)[0])
print('Position, Name, WAR+DWAR')
Analysis_function.All_Star_team(2017)
# Out:
# Best Pitcher, Name, WAR
# ('Corey Kluber', 8.0)
# Position, Name, WAR+DWAR
# {'2B': ['Jose Altuve', 9.0],
#  'RF': ['Mookie Betts', 9.0],
#  '1B': ['Joey Votto', 7.7],
#  '3B': ['Nolan Arenado', 9.5],
#  'SS': ['Andrelton Simmons', 11.3],
#  'CF': ['Mike Trout', 6.3],
#  'LF': ['Tommy Pham', 7.4],
#  'C': ['Willson Contreras', 5.3]}

# %% [markdown]
# ### 2. Historical All-Star team, use the similar model above to run out an All-star team in the whole period.

# %%
print('Position, Name, WAR+DWAR', 'Year')
Analysis_function.historical_all_star()
# Out:
# Position, Name, WAR+DWAR Year
# {'LF': ['Barry Bonds', 10.9, 2002],
#  'CF': ['Carlos Gomez', 13.0, 2013],
#  '1B': ['Albert Pujols', 10.7, 2007],
#  'C': ['Yadier Molina', 9.3, 2012],
#  '2B': ['Chase Utley', 12.3, 2008],
#  'SS': ['Alex Rodriguez', 12.399999999999999, 2000],
#  '3B': ['Scott Rolen', 12.2, 2004],
#  'RF': ['Mookie Betts', 12.700000000000001, 2018],
#  'P': ['Dwight Gooden', 11.9, 1985]}

# %% [markdown]
# ### 3. Specific Team's All-Star, use a similar model to find an All-star team in a specific team.

# %%
print("Position  Name  WAR+DWAR  Year")
Analysis_function.get_All_Period_Star_Specific_Team('NYY')
# Out:
# Position  Name  WAR+DWAR  Year
# {'C': ['Jorge Posada', 6.3, 2003],
#  '3B': ['Alex Rodriguez', 9.4, 2005],
#  'RF': ['Aaron Judge', 8.4, 2017],
#  '1B': ['Jason Giambi', 5.8, 2002],
#  'CF': ['Bernie Williams', 7.699999999999999, 1995],
#  'LF': ['Brett Gardner', 10.3, 2010],
#  'SS': ['Derek Jeter', 8.4, 1998],
#  '2B': ['Robinson Cano', 10.1, 2012],
#  'P': ['Andy Pettitte', 8.0, 1997]}

# %%
print("Position  Name  WAR+DWAR  Year")
Analysis_function.get_All_Period_Star_Specific_Team('LAD')
# Out:
# Position  Name  WAR+DWAR  Year
# {'SS': ['Corey Seager', 7.3, 2017],
#  'C': ['Russell Martin', 2.9000000000000004, 2010],
#  'RF': ['Cody Bellinger', 10.9, 2019],
#  '1B': ['Cody Bellinger', 4.4, 2018],
#  'CF': ['Matt Kemp', 7.6, 2011],
#  '2B': ['Mark Ellis', 4.6, 2013],
#  '3B': ['Justin Turner', 6.5, 2017],
#  'LF': ['Carl Crawford', 2.0, 2014],
#  'P': ['Zack Greinke', 9.3, 2015]}

# %% [markdown]
# ### 4. Build the rank list of the country/city would have produced good players to MLB.

# %%
Analysis_function.country_count()
# Out:
# [('USA', 405),
#  ('Dominican Republic', 67),
#  ('Venezuela', 61),
#  ('Cuba', 18),
#  ('Puerto Rico', 14),
#  ('Japan', 8),
#  ('Canada', 7),
#  ('Mexico', 7),
#  ('Curacao', 6),
#  ('Colombia', 5),
#  ('South Korea', 5),
#  ('Aruba', 3),
#  ('Brazil', 2),
#  ('Nicaragua', 2),
#  ('Panama', 2),
#  ('Taiwan', 2),
#  ('Australia', 1),
#  ('Germany', 1),
#  ('Netherlands', 1)]

# %%
Analysis_function.state_count()
# Out:
# [('', 198),
#  ('CA', 91),
#  ('FL', 47),
#  ('TX', 42),
#  ('GA', 20),
#  ('NC', 13),
#  ('NY', 13),
#  ('IL', 11),
#  ('OH', 11),
#  ('OK', 11),
#  ('TN', 10),
#  ('NJ', 9),
#  ('WA', 9),
#  ('CO', 8),
#  ('IN', 7),
#  ('LA', 7),
#  ('SC', 7),
#  ('AL', 6),
#  ('MO', 6),
#  ('OR', 6),
#  ('PA', 6),
#  ('VA', 6),
#  ('CT', 5),
#  ('DE', 5),
#  ('MS', 5),
#  ('AZ', 4),
#  ('DC', 4),
#  ('MA', 4),
#  ('MD', 4),
#  ('NV', 4),
#  ('AR', 3),
#  ('HI', 3),
#  ('NE', 3),
#  ('ON', 3),
#  ('BC', 2),
#  ('IA', 2),
#  ('KS', 2),
#  ('KY', 2),
#  ('MI', 2),
#  ('NM', 2),
#  ('Sonora', 2),
#  ('WI', 2),
#  ('AB', 1),
#  ('AK', 1),
#  ('ME', 1),
#  ('Michoacan', 1),
#  ('Nuevo Leon', 1),
#  ('QC', 1),
#  ('Sinaloa', 1),
#  ('Tamaulipas', 1),
#  ('UT', 1),
#  ('Veracruz', 1)]

# %%
Analysis_function.city_count()
# Out:
# [('Santo Domingo', 15),
#  ('Valencia', 12),
#  ('Maracay', 9),
#  ('Houston', 8),
#  ('San Diego', 8),
#  ('Maracaibo', 7),
#  ('San Pedro de Macoris', 7),
#  ('Caracas', 6),
#  ('Miami', 6),
#  ('Santiago', 6),
#  ('Atlanta', 5),
#  ('Bayamon', 5),
#  ('Havana', 5),
#  ('Washington', 5),
#  ('Lakeland', 4),
#  ('Las Vegas', 4),
#  ('Newark', 4),
#  ('Orlando', 4),
#  ('Pittsburgh', 4),
#  ('Willemstad', 4),
#  ('Wilmington', 4),
#  ('Austin', 3),
#  ('Bani', 3),
#  ('Cartagena', 3),
#  ('Charlotte', 3),
#  ('Cincinnati', 3),
#  ('Denver', 3),
#  ('Fort Worth', 3),
#  ('Hialeah', 3),
#  ('Jacksonville', 3),
#  ('Long Beach', 3),
#  ('Los Angeles', 3),
#  ('Nashville', 3),
#  ('Newport Beach', 3),
#  ('Riverside', 3),
#  ('San Cristobal', 3),
#  ('San Francisco', 3),
#  ('Santa Barbara', 3),
#  ('Santa Monica', 3),
#  ('Tulsa', 3),
#  ('Visalia', 3),
#  ('Albuquerque', 2),
#  ('Alexandria', 2),
#  ('Athens', 2),
#  ('Azua', 2),
#  ('Barquisimeto', 2),
#  ('Birmingham', 2),
# ...

# %% [markdown]
# ~~~
# We can find that most of the MLB players are from the USA, and there are about 22% of the stars are from California!
# Even almost doubles of the second-highest state.
# Surprisingly, the second place is in Florida, I thought it may be Texas when I was doing the research.
# By these statistics, a team could distribute their scouts due to the percentage of where might produce more stars to optimize their efficiency.
# However, there are still too many players do not have their birth record. Moreover, just as I mentioned above,
# some of the players from other countries may not be recorded, thus the result may overestimate the percentage of stars from the USA.
# ~~~

# %% [markdown]
# ### 5. Find the Expect year that a good player can be employed in MLB.

# %%
Analysis_function.expect_year_of_player()
# Out:
# Expect year that a good player can be employed in MLB :  11.168134507606085
# [('Rickey Henderson', 25),
#  ('Carlton Fisk', 24),
#  ('Omar Vizquel', 24),
#  ('Pete Rose', 24),
#  ('Dave Winfield', 23),
#  ('Julio Franco', 23),
#  ('Rusty Staub', 23),
#  ('Tim Raines Sr.', 23),
#  ('Alex Rodriguez', 22),
#  ('Barry Bonds', 22),
#  ('Bill Buckner', 22),
#  ('Gary Sheffield', 22),
#  ('Harold Baines', 22),
#  ('Jim Thome', 22),
#  ('Joe Morgan', 22),
#  ('Ken Griffey Jr.', 22),
#  ('Adrian Beltre', 21),
#  ('Andre Dawson', 21),
#  ('Cal Ripken', 21),
#  ('Darrell Evans', 21),
#  ('Eddie Murray', 21),
#  ('George Brett', 21),
#  ('Iván Rodríguez', 21),
#  ('Paul Molitor', 21),
#  ('Reggie Jackson', 21),
#  ('Ted Simmons', 21),
#  ('Alan Trammell', 20),
#  ('Benito Santiago', 20),
#  ('Brian Downing', 20),
#  ('Carlos Beltran', 20),
#  ('Craig Biggio', 20),
#  ('David Ortiz', 20),
#  ('Derek Jeter', 20),
#  ('Dwight Evans', 20),
#  ('Gary Gaetti', 20),
#  ('Jason Giambi', 20),
# ...

# %%
Analysis_function.expect_year_of_pitcher()
# Out:
# Expect year that a good pitcher can be employed in MLB :  10.168350168350168
# [('Nolan Ryan', 27),
#  ('Tommy John', 26),
#  ('Charlie Hough', 25),
#  ('Jamie Moyer', 25),
#  ('Dennis Eckersley', 24),
#  ('Phil Niekro', 24),
#  ('Roger Clemens', 24),
#  ('Steve Carlton', 24),
#  ('Dennis Martinez', 23),
#  ('Don Sutton', 23),
#  ('Greg Maddux', 23),
#  ('Bert Blyleven', 22),
#  ('Gaylord Perry', 22),
#  ('Jerry Reuss', 22),
#  ('Joe Niekro', 22),
#  ('Mike Morgan', 22),
#  ('Randy Johnson', 22),
#  ('Tom Glavine', 22),
#  ('Bartolo Colon', 21),
#  ('Danny Darwin', 21),
#  ('David Wells', 21),
#  ('Frank Tanana', 21),
#  ('John Smoltz', 21),
#  ('LaTroy Hawkins', 21),
#  ('Rick Honeycutt', 21),
#  ('Tom Gordon', 21),
#  ('Curt Schilling', 20),
#  ('Darren Oliver', 20),
#  ('Kenny Rogers', 20),
#  ('Terry Mulholland', 20),
#  ('Tom Seaver', 20),
#  ('Al Leiter', 19),
#  ('Bob McClure', 19),
#  ('CC Sabathia', 19),
#  ('Doyle Alexander', 19),
#  ('Fergie Jenkins', 19),
# ...

# %% [markdown]
# ~~~
# For top players (such as ranked at list once in top 100 AVG),
# those players usually can survive in MLB for about 11.16 years.
# However, for top pitchers (such as ranked at list once in the top 100 ERA),
# those pitchers can only survive in MLB for about 10.16 years.
# ~~~

# %% [markdown]
# ### 6. Find the Expect year that a good player can be ranked in the top 100 of AVG/ERA.

# %%
Analysis_function.expect_year_of_good_player()
# Out:
# The Expect year that a good player can be ranked in the top 100 of AVG/ERA :  3.194888178913738
# [('Harold Baines', 17),
#  ('Tony Gwynn', 17),
#  ('Derek Jeter', 16),
#  ('Manny Ramirez', 16),
#  ('Wade Boggs', 16),
#  ('Barry Bonds', 15),
#  ('Paul Molitor', 15),
#  ('Vladimir Guerrero', 15),
#  ('Miguel Cabrera', 14),
#  ('Tim Raines Sr.', 14),
#  ('Alex Rodriguez', 13),
#  ('Barry Larkin', 13),
#  ('Chipper Jones', 13),
#  ('Gary Sheffield', 13),
#  ('Ichiro Suzuki', 13),
#  ('Julio Franco', 13),
#  ('Mark Grace', 13),
#  ('Rickey Henderson', 13),
#  ('Robinson Cano', 13),
#  ('Will Clark', 13),
#  ('Albert Pujols', 12),
#  ('Brett Butler', 12),
#  ('Don Mattingly', 12),
#  ('Edgar Martinez', 12),
#  ('George Brett', 12),
#  ('Iván Rodríguez', 12),
#  ('Jeff Bagwell', 12),
#  ('Joe Mauer', 12),
#  ('Kirby Puckett', 12),
#  ('Larry Walker', 12),
#  ('Magglio Ordonez', 12),
#  ('Placido Polanco', 12),
#  ('Roberto Alomar', 12),
#  ('Todd Helton', 12),
#  ('Willie McGee', 12),
# ...

# %%
Analysis_function.expect_year_of_good_pitcher()
# Out:
# The Expect year that a good pitcher can be ranked in the top 100 of AVG/ERA :  4.021324354657688
# [('Greg Maddux', 22),
#  ('Tom Glavine', 20),
#  ('Roger Clemens', 19),
#  ('Jamie Moyer', 17),
#  ('Mike Mussina', 17),
#  ('Randy Johnson', 17),
#  ('CC Sabathia', 16),
#  ('Mark Buehrle', 15),
#  ('Andy Pettitte', 14),
#  ('Bartolo Colon', 14),
#  ('Chuck Finley', 14),
#  ('David Wells', 14),
#  ('Jack Morris', 14),
#  ('Livan Hernandez', 14),
#  ('Curt Schilling', 13),
#  ('Frank Tanana', 13),
#  ('Javier Vazquez', 13),
#  ('John Lackey', 13),
#  ('John Smoltz', 13),
#  ('Justin Verlander', 13),
#  ('Kenny Rogers', 13),
#  ('Kevin Brown', 13),
#  ('Orel Hershiser', 13),
#  ('Bob Welch', 12),
#  ('Charlie Hough', 12),
#  ('David Cone', 12),
#  ('Dennis Martinez', 12),
#  ('Felix Hernandez', 12),
#  ('John Burkett', 12),
#  ('Jon Lester', 12),
#  ('Kevin Appier', 12),
#  ('Kevin Millwood', 12),
#  ('Nolan Ryan', 12),
#  ('Steve Trachsel', 12),
#  ('Tim Hudson', 12),
# ...

# %% [markdown]
# ~~~~
# We know that each top player can survive in MLB for about 11.16 years.
# However, they can only be ranked as top players for about 3.19 years.
# In other words, they only contribute much for about three years to their team.
# This means that for the rest of their 8 years, they are not likely to be the Main Players of their team.
# They are just bench players.
#
# We also know that for each top pitchers can survive in MLB for about 10.16 years.
# Amazingly, they can be ranked as top pitchers for about 4.02 years, which is more than the average of players!
# In other words, they contribute a lot to more than half of their career time.
#
# In conclusion of (5) and (6). We can know that a good pitcher can contribute more than a good player (or batter) on average.
# But their career life surprisingly is far less than a player.
# Some possible assumption may due to pitchers are more likely to be injured, and the positions are fewer than fielders,
# thus a good pitcher can usually stand for their team for a long period and crowd out some rookies' opportunity.
# ~~~~

# %% [markdown]
# ### 7. Get Total WAR for the team in a specific year

# %%
AL = ['BAL', 'BOS', 'NYY', 'TB', 'TOR', 'CWS', 'CLE', 'DET', 'KC', 'MIN', 'HOU', 'LAA', 'OAK', 'SEA', 'TEX']
NL = ['ATL', 'MIA', 'NYM', 'PHI', 'WSH', 'CHC', 'CIN', 'MIL', 'PIT', 'STL', 'ARI', 'COL', 'LAD', 'SD', 'SF']

# %%
Analysis_function.All_Star_team(2019)
# Out:
# {'RF': ['Cody Bellinger', 10.9],
#  '3B': ['Alex Bregman', 9.6],
#  'CF': ['Mike Trout', 8.600000000000001],
#  'SS': ['Marcus Semien', 9.6],
#  '2B': ['Kolten Wong', 6.4],
#  'LF': ['Michael Brantley', 4.8],
#  '1B': ['Freddie Freeman', 3.9000000000000004],
#  'C': ['J.T. Realmuto', 6.1000000000000005]}

# %%
Analysis_function.total_WAR(2019)
# Out:
# [('HOU', 35.300000000000004),
#  ('NYY', 31.799999999999997),
#  ('LAD', 26.1),
#  ('BOS', 23.7),
#  ('ATL', 22.7),
#  ('OAK', 19.9),
#  ('WSH', 19.1),
#  ('MIL', 17.799999999999997),
#  ('MIN', 17.7),
#  ('LAA', 17.0),
#  ('ARI', 16.1),
#  ('CLE', 15.6),
#  ('TB', 14.700000000000003),
#  ('COL', 12.3),
#  ('NYM', 11.9),
#  ('CHW', 11.6),
#  ('PHI', 10.700000000000001),
#  ('BAL', 9.4),
#  ('KC', 9.299999999999999),
#  ('SF', 7.999999999999999),
#  ('Total', 7.9),
#  ('CIN', 7.6000000000000005),
#  ('CHC', 7.4),
#  ('MIA', 7.3999999999999995),
#  ('TEX', 7.299999999999999),
#  ('SEA', 7.100000000000001),
#  ('SD', 6.4),
#  ('STL', 4.5),
#  ('PIT', 2.7),
#  ('TOR', 1.7999999999999998),
#  ('DET', 0.4000000000000001)]

# %% [markdown]
# ~~~
# We can find that the total WAR of the batters has a high correlation to their team's performance.
# NYY HOU and LAD are all the first play in their division.
# ~~~
